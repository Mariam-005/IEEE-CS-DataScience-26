# %% [markdown]
# ### cleaning data

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv"
df = pd.read_csv(url)

# %% [markdown]
# dropna()-> dropna(axis='index' , how='any')  -> drop any row with missing vals
# dropna (axis= 'index' , how= 'all') -> will drop only the rows where all values are missing
# #for columns
# dropna(axis='columns' , how='any')

# %% [markdown]
# Missing Values?? - isna( )
# If there are any missing value in that column
# any()
# sum() -> Count the number of NaN in each column

# %%
df.isna(). any()
# Out:
# Date         False
# Open         False
# High         False
# Low          False
# Close        False
# Volume       False
# Adj Close    False
# dtype: bool

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %% [markdown]
# to replace missing values with another value ??
# .fillna()

# %% [markdown]
# casting Datatypes ??
# converting data from one data type to another
# .astype()

# %%
df.head()
# Out:
#          Date   Open   High    Low  Close    Volume  Adj Close
# 0  2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1  2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2  2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 3  2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 4  2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %%
df['Open'] = df['Open'].astype(int) 
df.head()
#convert from float to int
# Out:
#          Date  Open   High    Low  Close    Volume  Adj Close
# 0  2014-07-08    96  96.80  93.92  95.35  65130000      95.35
# 1  2014-07-07    94  95.99  94.10  95.97  56305400      95.97
# 2  2014-07-03    93  94.10  93.20  94.03  22891800      94.03
# 3  2014-07-02    93  94.06  93.09  93.48  28420900      93.48
# 4  2014-07-01    93  94.07  93.13  93.52  38170200      93.52

# %% [markdown]
# Working with datetime?

# %%
df.set_index('Date', inplace=True)

# %%
df
# Out:
#             Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-07-08    96  96.80  93.92  95.35   65130000      95.35
# 2014-07-07    94  95.99  94.10  95.97   56305400      95.97
# 2014-07-03    93  94.10  93.20  94.03   22891800      94.03
# 2014-07-02    93  94.06  93.09  93.48   28420900      93.48
# 2014-07-01    93  94.07  93.13  93.52   38170200      93.52
# ...          ...    ...    ...    ...        ...        ...
# 1980-12-18    26  26.75  26.63  26.63   18362400       0.41
# 1980-12-17    25  26.00  25.87  25.87   21610400       0.40
# 1980-12-16    25  25.37  25.25  25.25   26432000       0.39
# 1980-12-15    27  27.38  27.25  27.25   43971200       0.42
# 1980-12-12    28  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 6 columns]

# %%
#Filtering & Slicing
df[df['Close'] > 100]
# Out:
#             Open    High     Low   Close     Volume  Adj Close
# Date
# 2014-06-06   649  651.26  644.47  645.57   87484600      92.22
# 2014-06-05   646  649.37  642.61  647.35   75951400      92.48
# 2014-06-04   637  647.89  636.11  644.82   83870500      92.12
# 2014-06-03   628  638.74  628.25  637.54   73177300      91.08
# 2014-06-02   633  634.83  622.50  628.65   92337700      89.81
# ...          ...     ...     ...     ...        ...        ...
# 1999-12-07   116  118.00  114.00  117.81  111255200       4.02
# 1999-12-06   114  117.31  111.44  116.00  116695600       3.96
# 1999-12-03   112  115.56  111.88  115.00  161980000       3.93
# 1999-12-02   103  110.62  101.75  110.19  141839600       3.76
# 1999-12-01   101  104.50  100.06  103.06  154641200       3.52
#
# [1788 rows x 6 columns]

# %%
df.reset_index(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8465 entries, 0 to 8464
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8465 non-null   str
#  1   Open       8465 non-null   int64
#  2   High       8465 non-null   float64
#  3   Low        8465 non-null   float64
#  4   Close      8465 non-null   float64
#  5   Volume     8465 non-null   int64
#  6   Adj Close  8465 non-null   float64
# dtypes: float64(4), int64(2), str(1)
# memory usage: 463.1 KB

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Date'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 8465 entries, 0 to 8464
# Series name: Date
# Non-Null Count  Dtype
# --------------  -----
# 8465 non-null   datetime64[us]
# dtypes: datetime64[us](1)
# memory usage: 66.3 KB

# %%
df['Date'].max() -  df['Date'].min()
# Out:
# Timedelta('12261 days 00:00:00')

# %%
df=df.set_index('Date')

# %%
df.sort_index(inplace=True)

# %%
df['2014-07':'2014-08']['Close'].mean()
# Out:
# np.float64(94.47)

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.plot(df['Close'])  
plt.show()
